# %% [markdown]
# # Get Data

# %% [markdown]
# This file downloads the measurement set and images used by the other jupyter notebooks and scripts contained within the CASA Guide.

# %%
import os
os.system('pip install casatools')
os.system('pip install casatasks')
os.system('pip install astropy')
os.system("pip install 'build< 0.10.0'")
os.system('pip3 install --index-url=https://go.nrao.edu/pypi casadata')

if os.path.exists('./MWC_480_CO_220GHz.bin_30s.ms.cvel')== False:
    os.system('wget https://virginia.box.com/shared/static/9xtv12yxvl9wm7suwk515vvogzlucguv -O measurementset.tar')
    os.system('tar -xvf measurementset.tar')
else:
    print('You already have the Measurement set')
if os.path.exists('Images')== False:
    os.system('wget https://virginia.box.com/shared/static/47niq8a922obka7pd8217n3kmv3vefgi -O Images.tar.gz')
    os.system('tar -xzf Images.tar.gz')
else:
    print('You already have the Images')
if os.path.exists('premadeMask')== False:
    os.system('wget https://virginia.box.com/shared/static/i1apty2kjoar5ophrxj93rcrulck0txe -O premadeMask.tar.gz')
    os.system('tar -xzf premadeMask.tar.gz')
else:
    print('You already have the Masks')
# Out:
# ...
#   Obtaining dependency information for astropy from https://files.pythonhosted.org/packages/4e/49/13751fddb93336d043530cec634ba0f783797ac7550c84bf068cf5eea0fa/astropy-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for pyerfa>=2.0.1.1 from https://files.pythonhosted.org/packages/b3/1c/023031381b4cbc619eae5328d536735ec468218a2e92f45560bab9bb59a3/pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for astropy-iers-data>=0.2024.2.26.0.28.55 from https://files.pythonhosted.org/packages/7f/1c/3c63734aecfaec7abcca802e38d6e351a7887c794605dce5523df64f11da/astropy_iers_data-0.2024.4.29.0.28.48-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 23.7 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.7 MB/s eta 0:00:00 0:00:01m
# ...

# %%
# Out:
# MWC_480_CO_220GHz.bin_30s.ms.cvel/
# MWC_480_CO_220GHz.bin_30s.ms.cvel/table.f3
# MWC_480_CO_220GHz.bin_30s.ms.cvel/table.f9
# MWC_480_CO_220GHz.bin_30s.ms.cvel/table.lock
# MWC_480_CO_220GHz.bin_30s.ms.cvel/table.f16
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/table.dat
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/table.info
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/table.lock
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/table.f0
# MWC_480_CO_220GHz.bin_30s.ms.cvel/SYSCAL/table.f0i
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/table.info
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/table.f0i
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/table.f0
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/table.dat
# MWC_480_CO_220GHz.bin_30s.ms.cvel/ASDM_SBSUMMARY/table.lock
# MWC_480_CO_220GHz.bin_30s.ms.cvel/STATE/
# MWC_480_CO_220GHz.bin_30s.ms.cvel/STATE/table.dat
# ...
